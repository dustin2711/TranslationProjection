# %%
import json
import sys
import os

sys.path.append(os.path.abspath(".."))
from get_openai_translations import get_openai_translations
import helper
from enums import TranslationDirection


# words = ["Japanese", "is", "considered", "one", "of", "the", "hardest", "languages", "to", "learn"]
# translations1 = get_openai_translations(words, TranslationDirection.ENGLISH_TO_JAPANESE)

# # Test OpenAI
# response = helper.picke_load(
#     r"C:\Users\sens\Desktop\FingernailProjection\FingernailProjection\standstill_ocr_response.pkl"
# )
# paragraph_detection = response.paragraph_detections[0]
# words = [detection.text for detection in paragraph_detection.children]
# translations2 = get_openai_translations(words, TranslationDirection.ENGLISH_TO_JAPANESE)

output = """{ "The": "その", "world's": "世界の", "best": "最高の", "robots": "ロボット", "guide": "ガイド" }"""
json_dict = json.loads(output)
translation = json_dict["world's"]
print(translation)
# Out:
# 世界の
