# %%
import sys
import os
sys.path.append(os.path.abspath(".."))
import cv2
from pylon_image_capture import PylonImageCapture
from plotting import *
import plotting
from tkinter import Tk
from tkinter.filedialog import asksaveasfilename
# path = asksaveasfilename(
#     title="Save Image As",
#     filetypes=[("Image Files", "*.jpg *.png"), ("All Files", "*.*")]
# )

image = PylonImageCapture().get_image()
plotting.plot_bgr_image(image, title="Captured Image")
path = "C:\Users\sens\Desktop\FingernailProjection\FingernailProjection\prototyping\hand_dataset\background_image.jpg"
cv2.imwrite(path, image)
print(f"Wrote image to {path}")
