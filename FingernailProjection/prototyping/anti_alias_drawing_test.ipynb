# %%
import sys
import os

sys.path.append(os.path.abspath(".."))
from enums import Anchor
import cv2
from drawing import draw_polygon, draw_roated_text, get_font
from aadrawing import draw_thin_polygon
from typing import List, Tuple
import numpy as np

# Example usage
image = np.zeros((500, 500, 3), dtype=np.uint8)
points = [(100, 100), (400, 102), (300, 400), (100, 300)]
draw_thin_polygon(image, points, (0, 255, 0))

points = [(120, 120), (420, 122), (320, 420), (120, 320)]
draw_polygon(image, points, (0, 255, 0), 1, True)

draw_roated_text(
    image,
    "Das ist ein Test",
    (100, 100),
    0,
    Anchor.BOTTOM,
    get_font(
        30,
        r"C:\\Users\\sens\\Desktop\\FingernailProjection\\FingernailProjection\\ARTranslator-master\\Koruri-Regular.ttf",
    ),
    (0, 255, 0),
    use_ascend_and_descend=True,
)


cv2.imshow("AA Polygon", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
