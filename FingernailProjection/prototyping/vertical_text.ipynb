# %%
import math
import sys
import os

sys.path.append(os.path.abspath(".."))

from enums import *
import drawing
import matlike_utils
from drawing import *
import plotting


center = 100
diameter = 200
center_tuple = (center, center)
diameter_tuple = (diameter, diameter)
text_size = 40

font = drawing.get_font(
    text_size,
    r"C:\Users\sens\Desktop\FingernailProjection\FingernailProjection\ARTranslator-master\Koruri-Regular.ttf",
)


image = matlike_utils.create_pillow_vertical_text_image("ロボイ", font, BLACK, spacing_factor=0)
plotting.plot_rgb_image(np.array(image))

text = join_string("ロボイ", "\n")
image = matlike_utils.create_pillow_text_image(text, font, BLACK, use_ascend_and_descend=False)
plotting.plot_rgb_image(np.array(image))
